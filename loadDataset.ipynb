# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevangi/sketch-to-face-synthesis/blob/main/loadDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.listdir('/content/drive/MyDrive')
# Out:
# ['Colab Notebooks', 'Sketch2Face']

# %%
os.listdir('/content/drive/MyDrive/Sketch2Face')
# Out:
# []

# %%
# !mkdir /content/drive/MyDrive/Sketch2Face/dataset

# %%
# !ls /content/drive/MyDrive/Sketch2Face
# Out:
# dataset

# %%
from google.colab import files
files.upload()

# %%
# !ls
# Out:
# drive  kaggle.json  sample_data

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list | head
# Out:
# ref                                                          title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# dmahajanbe23/bmw-global-automotive-sales                     BMW Global Automotive Sales                              55017  2026-02-22 18:18:38.170000           9526        188                1
# ssssws/chocolate-sales-dataset-2023-2024                     Chocolate Sales Dataset 2023 - 2024                   24420255  2026-03-07 04:58:02.387000           2769         56                1
# jayjoshi37/sleep-screen-time-and-stress-analysis             Sleep, Screen Time and Stress Analysis                  310158  2026-03-11 14:21:59.017000           1321         27                1
# ...

# %%
# !kaggle datasets download -d arbazkhan971/cuhk-face-sketch-database-cufs -p /content/drive/MyDrive/Sketch2Face/dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arbazkhan971/cuhk-face-sketch-database-cufs
# License(s): copyright-authors
# ...
# 100% 113M/113M [00:00<00:00, 126MB/s]

# %%
# !ls drive/MyDrive/Sketch2Face/dataset
# Out:
# cuhk-face-sketch-database-cufs.zip

# %%
import zipfile

# %%
zip_path = "/content/drive/MyDrive/Sketch2Face/dataset/cuhk-face-sketch-database-cufs.zip"
extract_path = "/content/drive/MyDrive/Sketch2Face/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# %%
# !ls drive/MyDrive/Sketch2Face/dataset
# Out:
# cropped_sketch			    photo	  sketch
# cuhk-face-sketch-database-cufs.zip  photo_points  sketches
# original_sketch			    photos	  sketch_points

# %%
import os

# %%
base_path = "drive/MyDrive/Sketch2Face/dataset"

# %%
sketch_dir = os.path.join(base_path, "sketches")
photo_dir  = os.path.join(base_path, "photos")

print("Sketch images:", len(os.listdir(sketch_dir)))
print("Photo images :", len(os.listdir(photo_dir)))
# Out:
# Sketch images: 188
# Photo images : 188

# %%
def normalize_sketch_name(name):
    name = name.lower()

    # remove _sz1
    name = name.replace("-sz1", "")

    # replace M2 → m and F2 → f
    if name.startswith("m2"):
        name = name.replace("m2", "m", 1)
    if name.startswith("f2"):
        name = name.replace("f2", "f", 1)

    return name

# %%
photo_files = os.listdir(photo_dir)
photo_dict = {p.lower(): p for p in photo_files}

# %%
paired = []
missing = []

# %%
for sketch in os.listdir(sketch_dir):
    normalized_name = normalize_sketch_name(sketch)

    if normalized_name in photo_dict:
        paired.append((sketch, photo_dict[normalized_name]))
    else:
        missing.append(sketch)

# %%
print("Total paired samples:", len(paired))
print("Total missing sketches:", len(missing))
# Out:
# Total paired samples: 188
# Total missing sketches: 0
